# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/usamakhan/Downloads/PAI/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#df['Sex'].value_counts()
sns.lineplot(x="Embarked",y="Age",data=df,hue='Sex',markers=True,style="Pclass")
plt.show()

# %%
sns.barplot(x='Embarked',y="Age",data=df,hue='Pclass',palette='rocket')
plt.show()
# Out:
# /home/usamakhan/.local/lib/python3.10/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
pf=pd.read_csv("/home/usamakhan/Downloads/PAI/Social_Network_Ads.csv")
pf
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
sns.scatterplot(x='Age',y="EstimatedSalary",data=pf,style="Purchased",hue="Purchased")
plt.show()

# %%
sns.displot(x='EstimatedSalary',data=pf,color='y')
plt.show()

# %%
sns.boxplot(x='Age',y="EstimatedSalary",data=pf,hue="Purchased")
plt.show()

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704
